# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Times.txt', sep=";")

# %%
data
# Out:
#     threads     time     img  filter
# 0         1   203660  262144       9
# 1         2    99127  262144       9
# 2         4    49123  262144       9
# 3         8    44999  262144       9
# 4         1   365705  262144      16
# 5         2   192775  262144      16
# 6         4    89027  262144      16
# 7         8    51186  262144      16
# 8         1   561534  262144      25
# 9         2   279075  262144      25
# 10        4   139565  262144      25
# 11        8    91676  262144      25
# 12        1   801760  262144      36
# 13        2   399361  262144      36
# 14        4   197438  262144      36
# 15        8   129735  262144      36
# 16        1  1085532  262144      49
# 17        2   536318  262144      49
# 18        4   268508  262144      49
# 19        8   182471  262144      49
# 20        1  1438716  262144      64
# 21        2   722937  262144      64
# 22        4   353970  262144      64
# 23        8   227865  262144      64
# 24        1  1807644  262144      81
# 25        2   905770  262144      81
# 26        4   452659  262144      81
# 27        8   301104  262144      81
# 28        1  2198084  262144     100
# 29        2  1095139  262144     100
# ..      ...      ...     ...     ...
# 34        4   682486  262144     121
# 35        8   408118  262144     121
# 36        1  3160270  262144     144
# 37        2  1633685  262144     144
# 38        4   785972  262144     144
# 39        8   477099  262144     144
# 40        1  3746073  262144     169
# 41        2  1880406  262144     169
# 42        4   925471  262144     169
# 43        8   556343  262144     169
# 44        1  4346922  262144     196
# 45        2  2191540  262144     196
# 46        4  1069271  262144     196
# 47        8   683162  262144     196
# 48        1  4963610  262144     225
# 49        2  2515194  262144     225
# 50        4  1235043  262144     225
# 51        8   749875  262144     225
# 52        1  5910864  262144     256
# 53        2  2999854  262144     256
# 54        4  1490916  262144     256
# 55        8   919862  262144     256
# 56        1  6391568  262144     289
# 57        2  3263748  262144     289
# 58        4  1673120  262144     289
# 59        8   956308  262144     289
# 60        1  7241394  262144     324
# 61        2  3650451  262144     324
# 62        4  1793055  262144     324
# 63        8  1099972  262144     324
#
# [64 rows x 4 columns]

# %%
#data.plot(x = 'filter', y='time',)
plt.plot("filter", "time", data=data[data.threads==1])
plt.plot("filter", "time", data=data[data.threads==2])
plt.plot("filter", "time", data=data[data.threads==4])
plt.plot("filter", "time", data=data[data.threads==8])
plt.legend()
plt.show()
